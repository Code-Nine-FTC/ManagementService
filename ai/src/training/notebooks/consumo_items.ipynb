# %%
from training.data_extraction import load_monthly_consumption, get_item_series
df = load_monthly_consumption()
df.head()
# Out:
# A execução de células com 'Python 3.12.11' requer o pacote ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crie um ambiente Python</a> com os pacotes necessários.
#
# Ou instale 'ipykernel' usando o comando: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
from training.train_item_model import train_single_item
forecast, meta = train_single_item(item_id=1)
forecast, meta
